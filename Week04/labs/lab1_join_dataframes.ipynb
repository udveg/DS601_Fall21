# %% [markdown]
# https://realpython.com/pandas-merge-join-and-concat/

# %%
# what do we do if library doesn't exist??
# !pip install faker
# Out:
# Requirement already satisfied: faker in /Users/msarica/opt/anaconda3/lib/python3.8/site-packages (8.13.2)
# Requirement already satisfied: text-unidecode==1.3 in /Users/msarica/opt/anaconda3/lib/python3.8/site-packages (from faker) (1.3)
# Requirement already satisfied: python-dateutil>=2.4 in /Users/msarica/opt/anaconda3/lib/python3.8/site-packages (from faker) (2.8.1)
# Requirement already satisfied: six>=1.5 in /Users/msarica/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.4->faker) (1.15.0)

# %%
from faker import Faker
import pandas as pd
import random

# %%
f = Faker()

df1 = pd.DataFrame({
    'id': ['st_' + str(i) for i in range(0, 20)],
    'name': [f.name() for _ in range(0,20)],
    'email' : [f.email() for _ in range(0,20)]
})

# %%
df1
# Out:
#        id              name                       email
# 0    st_0   Joseph Thompson     priscilla84@hotmail.com
# 1    st_1         Nancy Lee     reneemorris@hotmail.com
# 2    st_2        Brian Owen   trevorcontreras@gmail.com
# 3    st_3      Craig Parker  bonniewood@richardson.info
# 4    st_4        Scott Hill           vdudley@yahoo.com
# 5    st_5     Zachary Jones          cmccoy@hotmail.com
# 6    st_6        John Cline      sandra49@daugherty.org
# 7    st_7    Sarah Callahan     shannonpotter@brown.com
# 8    st_8    Anthony Horton         amckenzie@gmail.com
# 9    st_9  Glenda Henderson            csmith@gmail.com
# 10  st_10        Mark Smith        zclark@kim-silva.com
# 11  st_11        Lori Morse          smcclure@yahoo.com
# 12  st_12     Deborah Brown      michaelcox@thomas.info
# 13  st_13     Jennifer Bean  johnsonkristen@chapman.com
# 14  st_14      Eric Collins     jamesadams@robinson.com
# 15  st_15     Teresa Torres        keithknapp@yahoo.com
# 16  st_16    Melissa Foster       ethanharris@gmail.com
# 17  st_17  Connie Maldonado     andersonkaren@gmail.com
# 18  st_18     Joanne Wagner          mary15@hotmail.com
# 19  st_19   Elizabeth Mckay    victoriakelley@yahoo.com

# %%
count = 25

df2 = pd.DataFrame({
    'studentId': ['st_' + str(i) for i in range(5, count)],
    'grade1': [random.randint(50, 100) for _ in range(5,count)],
    'grade2': [random.randint(50, 100) for _ in range(5,count)],
    'grade3': [random.randint(50, 100) for _ in range(5,count)],
})

# %%
df2
# Out:
#    studentId  grade1  grade2  grade3
# 0       st_5      95      92      59
# 1       st_6      84      72      97
# 2       st_7      57      87      66
# 3       st_8      87      86      87
# 4       st_9      78      66      79
# 5      st_10      67      56      85
# 6      st_11      76      60      83
# 7      st_12      88      85      67
# 8      st_13     100      85      55
# 9      st_14      91      72      65
# 10     st_15      66      55     100
# 11     st_16      89      62      67
# 12     st_17      57      92      62
# 13     st_18      83      81      91
# 14     st_19      69      53      62
# 15     st_20      65      69      56
# 16     st_21      68      87      87
# 17     st_22      96      53      64
# 18     st_23      83      51      72
# 19     st_24      51      89      57

# %% [markdown]
# ## Merge `df1` and `df2`: if students exist in both data frames

# %%
df_merged = pd.merge(df1, df2, how='inner', left_on='id', right_on='studentId')
df_merged
# Out:
#        id              name                       email studentId  grade1  \
# 0    st_5     Zachary Jones          cmccoy@hotmail.com      st_5      95
# 1    st_6        John Cline      sandra49@daugherty.org      st_6      84
# 2    st_7    Sarah Callahan     shannonpotter@brown.com      st_7      57
# 3    st_8    Anthony Horton         amckenzie@gmail.com      st_8      87
# 4    st_9  Glenda Henderson            csmith@gmail.com      st_9      78
# 5   st_10        Mark Smith        zclark@kim-silva.com     st_10      67
# 6   st_11        Lori Morse          smcclure@yahoo.com     st_11      76
# 7   st_12     Deborah Brown      michaelcox@thomas.info     st_12      88
# 8   st_13     Jennifer Bean  johnsonkristen@chapman.com     st_13     100
# 9   st_14      Eric Collins     jamesadams@robinson.com     st_14      91
# 10  st_15     Teresa Torres        keithknapp@yahoo.com     st_15      66
# 11  st_16    Melissa Foster       ethanharris@gmail.com     st_16      89
# 12  st_17  Connie Maldonado     andersonkaren@gmail.com     st_17      57
# 13  st_18     Joanne Wagner          mary15@hotmail.com     st_18      83
# 14  st_19   Elizabeth Mckay    victoriakelley@yahoo.com     st_19      69
#
#     grade2  grade3
# 0       92      59
# 1       72      97
# 2       87      66
# 3       86      87
# 4       66      79
# 5       56      85
# 6       60      83
# 7       85      67
# 8       85      55
# 9       72      65
# 10      55     100
# 11      62      67
# 12      92      62
# 13      81      91
# 14      53      62

# %% [markdown]
# ## Merge `df1` and `df2`: get all students from `df1` and get from `df2` if student exists on `df2`

# %%
df_merged = pd.merge(df1, df2, how='left', left_on='id', right_on='studentId')
df_merged
# Out:
#        id              name                       email studentId  grade1  \
# 0    st_0   Joseph Thompson     priscilla84@hotmail.com       NaN     NaN
# 1    st_1         Nancy Lee     reneemorris@hotmail.com       NaN     NaN
# 2    st_2        Brian Owen   trevorcontreras@gmail.com       NaN     NaN
# 3    st_3      Craig Parker  bonniewood@richardson.info       NaN     NaN
# 4    st_4        Scott Hill           vdudley@yahoo.com       NaN     NaN
# 5    st_5     Zachary Jones          cmccoy@hotmail.com      st_5    95.0
# 6    st_6        John Cline      sandra49@daugherty.org      st_6    84.0
# 7    st_7    Sarah Callahan     shannonpotter@brown.com      st_7    57.0
# 8    st_8    Anthony Horton         amckenzie@gmail.com      st_8    87.0
# 9    st_9  Glenda Henderson            csmith@gmail.com      st_9    78.0
# 10  st_10        Mark Smith        zclark@kim-silva.com     st_10    67.0
# 11  st_11        Lori Morse          smcclure@yahoo.com     st_11    76.0
# 12  st_12     Deborah Brown      michaelcox@thomas.info     st_12    88.0
# 13  st_13     Jennifer Bean  johnsonkristen@chapman.com     st_13   100.0
# 14  st_14      Eric Collins     jamesadams@robinson.com     st_14    91.0
# 15  st_15     Teresa Torres        keithknapp@yahoo.com     st_15    66.0
# 16  st_16    Melissa Foster       ethanharris@gmail.com     st_16    89.0
# 17  st_17  Connie Maldonado     andersonkaren@gmail.com     st_17    57.0
# 18  st_18     Joanne Wagner          mary15@hotmail.com     st_18    83.0
# 19  st_19   Elizabeth Mckay    victoriakelley@yahoo.com     st_19    69.0
#
#     grade2  grade3
# 0      NaN     NaN
# 1      NaN     NaN
# 2      NaN     NaN
# 3      NaN     NaN
# 4      NaN     NaN
# 5     92.0    59.0
# 6     72.0    97.0
# 7     87.0    66.0
# 8     86.0    87.0
# 9     66.0    79.0
# 10    56.0    85.0
# 11    60.0    83.0
# 12    85.0    67.0
# 13    85.0    55.0
# 14    72.0    65.0
# 15    55.0   100.0
# 16    62.0    67.0
# 17    92.0    62.0
# 18    81.0    91.0
# 19    53.0    62.0

# %% [markdown]
# ## Merge `df1` and `df2`: get all students from `df2` and get from `df1` if student exists on `df1`

# %%
df_merged = pd.merge(df1, df2, how='right', left_on='id', right_on='studentId')
df_merged
# Out:
#        id              name                       email studentId  grade1  \
# 0    st_5     Zachary Jones          cmccoy@hotmail.com      st_5      95
# 1    st_6        John Cline      sandra49@daugherty.org      st_6      84
# 2    st_7    Sarah Callahan     shannonpotter@brown.com      st_7      57
# 3    st_8    Anthony Horton         amckenzie@gmail.com      st_8      87
# 4    st_9  Glenda Henderson            csmith@gmail.com      st_9      78
# 5   st_10        Mark Smith        zclark@kim-silva.com     st_10      67
# 6   st_11        Lori Morse          smcclure@yahoo.com     st_11      76
# 7   st_12     Deborah Brown      michaelcox@thomas.info     st_12      88
# 8   st_13     Jennifer Bean  johnsonkristen@chapman.com     st_13     100
# 9   st_14      Eric Collins     jamesadams@robinson.com     st_14      91
# 10  st_15     Teresa Torres        keithknapp@yahoo.com     st_15      66
# 11  st_16    Melissa Foster       ethanharris@gmail.com     st_16      89
# 12  st_17  Connie Maldonado     andersonkaren@gmail.com     st_17      57
# 13  st_18     Joanne Wagner          mary15@hotmail.com     st_18      83
# 14  st_19   Elizabeth Mckay    victoriakelley@yahoo.com     st_19      69
# 15    NaN               NaN                         NaN     st_20      65
# 16    NaN               NaN                         NaN     st_21      68
# 17    NaN               NaN                         NaN     st_22      96
# 18    NaN               NaN                         NaN     st_23      83
# 19    NaN               NaN                         NaN     st_24      51
#
#     grade2  grade3
# 0       92      59
# 1       72      97
# 2       87      66
# 3       86      87
# 4       66      79
# 5       56      85
# 6       60      83
# 7       85      67
# 8       85      55
# 9       72      65
# 10      55     100
# 11      62      67
# 12      92      62
# 13      81      91
# 14      53      62
# 15      69      56
# 16      87      87
# 17      53      64
# 18      51      72
# 19      89      57

# %% [markdown]
# ## Merge `df1` and `df2`: get both records

# %%
df_merged = pd.merge(df1, df2, how='outer', left_on='id', right_on='studentId')
df_merged
# Out:
#        id              name                       email studentId  grade1  \
# 0    st_0   Joseph Thompson     priscilla84@hotmail.com       NaN     NaN
# 1    st_1         Nancy Lee     reneemorris@hotmail.com       NaN     NaN
# 2    st_2        Brian Owen   trevorcontreras@gmail.com       NaN     NaN
# 3    st_3      Craig Parker  bonniewood@richardson.info       NaN     NaN
# 4    st_4        Scott Hill           vdudley@yahoo.com       NaN     NaN
# 5    st_5     Zachary Jones          cmccoy@hotmail.com      st_5    95.0
# 6    st_6        John Cline      sandra49@daugherty.org      st_6    84.0
# 7    st_7    Sarah Callahan     shannonpotter@brown.com      st_7    57.0
# 8    st_8    Anthony Horton         amckenzie@gmail.com      st_8    87.0
# 9    st_9  Glenda Henderson            csmith@gmail.com      st_9    78.0
# 10  st_10        Mark Smith        zclark@kim-silva.com     st_10    67.0
# 11  st_11        Lori Morse          smcclure@yahoo.com     st_11    76.0
# 12  st_12     Deborah Brown      michaelcox@thomas.info     st_12    88.0
# 13  st_13     Jennifer Bean  johnsonkristen@chapman.com     st_13   100.0
# 14  st_14      Eric Collins     jamesadams@robinson.com     st_14    91.0
# 15  st_15     Teresa Torres        keithknapp@yahoo.com     st_15    66.0
# 16  st_16    Melissa Foster       ethanharris@gmail.com     st_16    89.0
# 17  st_17  Connie Maldonado     andersonkaren@gmail.com     st_17    57.0
# 18  st_18     Joanne Wagner          mary15@hotmail.com     st_18    83.0
# 19  st_19   Elizabeth Mckay    victoriakelley@yahoo.com     st_19    69.0
# 20    NaN               NaN                         NaN     st_20    65.0
# 21    NaN               NaN                         NaN     st_21    68.0
# 22    NaN               NaN                         NaN     st_22    96.0
# 23    NaN               NaN                         NaN     st_23    83.0
# 24    NaN               NaN                         NaN     st_24    51.0
#
#     grade2  grade3
# 0      NaN     NaN
# 1      NaN     NaN
# 2      NaN     NaN
# 3      NaN     NaN
# 4      NaN     NaN
# 5     92.0    59.0
# 6     72.0    97.0
# 7     87.0    66.0
# 8     86.0    87.0
# 9     66.0    79.0
# 10    56.0    85.0
# 11    60.0    83.0
# 12    85.0    67.0
# 13    85.0    55.0
# 14    72.0    65.0
# 15    55.0   100.0
# 16    62.0    67.0
# 17    92.0    62.0
# 18    81.0    91.0
# 19    53.0    62.0
# 20    69.0    56.0
# 21    87.0    87.0
# 22    53.0    64.0
# 23    51.0    72.0
# 24    89.0    57.0
