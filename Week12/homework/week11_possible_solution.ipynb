# %%
import pandas as pd
import random
from faker import Faker

class FakeDataGenerator:
    
    def __init__(self, df = None, rows=5):
        """
        This class generates fake data
        
        If data frame is passed in it will add the fake data to it. 
        Otherwise, it will create a new data frame
        
        Parameters:
        -----------
        df: 
          DataFrame default is None
          
        rows:
          If df None, this parameter will be used to create a data frame with `row` length
        """
        # code goes under this line. 
        # I will deduct points if any code is written above the comments!
          
        self.fake = Faker()
        
        if df is not None:
            self.df = df
            self.rows = len(df)
        else:
            self.df = pd.DataFrame()
            self.rows = rows
        
        
    def add_random_number(self, column_name, small_value, high_value): # optional: add probabilities 
        """
        adds fake numbers to the data frame with `column_name`
        
        Returns
        -------
        data frame
        """
        
        self.df[column_name] = [random.randint(small_value,high_value) for i in range(self.rows)]
        
        return self.df       
    
        
    def add_name(self, column_name):
        """
        adds fake name to the data frame with `column_name`
        
        Returns
        -------
        data frame
        """

        self.df[column_name] = [self.fake.first_name() for i in range(self.rows)]
        
        return self.df
    
    
    def add_last_name(self, column_name):
        """
        adds fake last name to the data frame with `column_name`
        
        Returns
        -------
        data frame
        """
        
        self.df[column_name] = [self.fake.last_name() for i in range(self.rows)]
        
        return self.df
    
    
    def add_email(self, column_name):
        """
        adds fake email to the data frame with `column_name`
        
        Returns
        -------
        data frame
        """

        self.df[column_name] = [self.fake.email() for i in range(self.rows)]
        
        return self.df
    
    
    def add_phone_number(self, column_name):
        """
        adds fake phone number to the data frame with `column_name`
        
        Returns
        -------
        data frame
        """
        
        self.df[column_name] = [self.fake.phone_number() for i in range(self.rows)]
        
        return self.df
    
    
    def add_address(self, column_name):
        """
        adds fake address to the data frame with `column_name`
        
        Returns
        -------
        data frame
        """
        
        self.df[column_name] = [self.fake.address() for i in range(self.rows)]
        
        return self.df

# %%
import pandas as pd

# Case 1 - existing data frame 
df = pd.DataFrame()
df['product_id'] = [i + 123 for i in range(25)]
df.head()
# Out:
#    product_id
# 0         123
# 1         124
# 2         125
# 3         126
# 4         127

# %%
fakeGen = FakeDataGenerator(df) # I'm creating instance using existing df
fakeGen.add_name('name')
fakeGen.add_last_name('lastname')
fakeGen.add_address('shipping_address')
fakeGen.add_address('billing_address')
fakeGen.add_phone_number('customer_phone')
# Out:
#     product_id      name   lastname  \
# 0          123    Sandra       Dyer
# 1          124     Sarah     Thomas
# 2          125     Anita     Wilson
# 3          126    Robert    Hawkins
# 4          127   Michael      Lloyd
# 5          128    Stacey      Adams
# 6          129     Donna     Thomas
# 7          130    Monica     Nguyen
# 8          131   Crystal     Bailey
# 9          132    Justin    Spencer
# 10         133   Jeffrey     Greene
# 11         134      Mark     Hudson
# 12         135    Pamela     Barnes
# 13         136     Kelly     Wright
# 14         137     Linda    Johnson
# 15         138    Thomas      Welch
# 16         139   William      Foley
# 17         140   Matthew      White
# 18         141    Joshua    Escobar
# 19         142      Ruth    Spencer
# 20         143   Brandon     Lawson
# 21         144  Jeremiah       Hall
# 22         145     Kevin       Cobb
# 23         146    Pamela  Mccormick
# 24         147   William      Smith
#
#                                      shipping_address  \
# 0               7575 Maria Grove\nMillsfurt, NM 82065
# 1               1977 Garza Land\nOrtizville, NC 50500
# 2              69941 Taylor Avenue\nRushton, IA 90035
# 3        93685 Williams Flat\nStephaniefort, VT 96274
# 4             264 Bailey Ridge\nPort Joseph, NV 42600
# 5                    Unit 7232 Box 6220\nDPO AP 65309
# 6    07258 Davis Streets\nPort Larrychester, WI 64002
# 7   43027 Thomas Club Apt. 655\nGonzaleztown, NJ 6...
# 8       162 Thornton Heights\nGwendolynstad, CO 86676
# 9                          USCGC Peters\nFPO AE 94027
# 10            198 Allison Lock\nCalderonton, DC 96374
# 11  0367 Reed Plain Apt. 575\nNew Jacqueline, IN 9...
# 12  724 Timothy Parkway Suite 393\nEast Mariaberg,...
# 13   7299 Roberts Creek Apt. 019\nDevinberg, AR 66374
# 14  33475 Christina Pass Suite 649\nNew Natalie, M...
# 15       49349 Daniel Spring\nSouth Lindsey, LA 94387
# 16                 340 Kelley View\nCoxport, KY 97070
# 17               68253 Bush Ramp\nShawmouth, DC 10543
# 18  7434 Amanda Course Apt. 572\nEast Derrickberg,...
# 19  20931 Melanie Pass Apt. 829\nRodriguezmouth, A...
# 20          077 Huang Skyway\nCassandrabury, KY 03934
# 21  395 Meadows Crest Suite 720\nPort Donaldville,...
# 22  02064 Nathan Lakes Apt. 138\nEast Stephanie, N...
# 23  282 Rogers Landing Apt. 843\nNorth Mariaville,...
# 24          65745 Roberson Divide\nGinaview, IL 62974
#
#                                       billing_address          customer_phone
# 0                            USNS Stone\nFPO AE 38583  001-202-323-4057x14729
# 1           25632 Hubbard Heights\nLisabury, NJ 14147        001-744-377-6564
# 2          58675 Mathis Pike\nSouth Anthony, AK 62983         +1-011-619-9337
# 3    41781 Frye Greens Suite 415\nParkerton, DE 89744       (363)607-2352x655
# 4             84139 Potter Path\nBensonland, MN 05925       231.028.6955x0621
# 5           616 Christopher Plaza\nNew Mark, WV 79591        919.908.6781x296
# 6       218 Casey Village\nNorth Ambermouth, NV 98777  001-609-793-3754x60619
# 7         22026 Page Pine\nNew Jeffreyhaven, WV 43809            571.178.0521
# 8      67817 Megan Circle\nPort Ginaborough, NJ 05970      996-402-4410x13998
# 9      519 Hardy Green Apt. 163\nHaleyhaven, NC 00904  001-601-849-1106x95940
# 10  8678 Taylor Island Apt. 333\nNorth Angel, OR 0...   001-027-723-2594x9202
# 11           46428 Cook Mission\nDanielland, SD 06298            893-393-6685
# 12   63369 Jamie Rapid Apt. 419\nSouth John, OR 04561              8612875340
# 13          7600 Jennifer Forks\nReevesbury, OH 09829              1234689890
# 14                   PSC 3738, Box 2185\nAPO AE 94771         +1-360-087-8479
# 15  970 Jonathan Passage Apt. 148\nWest Thomastown...            075.189.3079
# 16      4955 Anna River Apt. 796\nTonyafurt, NM 69991    +1-539-257-6968x6911
# 17        1765 Johnson Cliff\nNew Davidland, DC 54582           (813)480-1527
# 18                8169 Angela Ford\nMarkton, ND 66125       981-532-1865x1102
# 19           549 Bonnie Mission\nNew Stacey, MA 64732            077-719-0039
# 20  20265 Gates Turnpike Suite 709\nJennymouth, AK...    001-574-507-4139x545
# 21            7101 Hughes Point\nSmithmouth, KY 77680    +1-812-870-0407x6955
# 22            9186 Cole Burgs\nPort Belinda, WY 56742       514.369.8825x8154
# 23                         USNV Edwards\nFPO AP 22971         +1-757-755-6988
# 24  8007 Burgess Dam Suite 845\nWest Eddieborough,...      (219)861-5467x9838

# %%
# Case 2 - no dataframe

fakeGen = FakeDataGenerator() # no df
fakeGen.add_address('shipping_address')
fakeGen.add_address('billing_address')
fakeGen.add_phone_number('customer_phone')
fakeGen.add_random_number('sale_count', 10, 100)
# Out:
#                                     shipping_address  \
# 0                             USS Webb\nFPO AA 76331
# 1             85611 Nixon Forks\nTammyport, AK 32296
# 2       73596 Guy Lane\nLake Nathanielside, CT 15162
# 3  6137 Anderson Springs Apt. 159\nRichardburgh, ...
# 4               18180 Mann Keys\nPort Anna, SD 88978
#
#                                      billing_address          customer_phone  \
# 0   08841 Boone Centers\nNorth Sherryville, KS 67968    +1-024-889-3676x1590
# 1              13103 Day Cliffs\nBrianstad, AR 48555  001-585-824-7564x77972
# 2       931 Brittany Parks\nNorth Evanport, SD 32754           (709)948-6035
# 3  80534 Hebert Bypass Suite 981\nGonzalezhaven, ...      (061)688-8903x5229
# 4  342 Isaiah Squares Suite 881\nPort Sandra, NY ...              6430170602
#
#    sale_count
# 0          14
# 1          56
# 2          99
# 3          38
# 4          58
